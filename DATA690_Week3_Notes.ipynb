# %% [markdown]
# <a href="https://colab.research.google.com/github/tsnow2010/umbc_data690_fall2024/blob/main/DATA690_Week3_Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DATA690 Week 3

# %%
import random
random.randint(1,21)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e9c521931a50> in <cell line: 1>()
# ----> 1 randint(0,17)
#
# NameError: name 'randint' is not defined

# %%
# When you are making a count of something, try using dictionary!
# Code is concise, but it depends on a set of answers.

some_list = ['student', 'student', 'engineer', 'scientist'] #Imagine a list of responses to full-time job

counts = {}

for job in some_list:
  if job in counts:
    counts[job] += 1
  else:
    counts[job] = 1

print(counts)
# Out:
# {'student': 2, 'engineer': 1, 'scientist': 1}

# %%
# Here's a better way with pandas!

import pandas as pd

url = 'https://raw.githubusercontent.com/wcj365/python-stats-dataviz/master/data/UMBC%20DATA%20690%20FALL%202024%20DR%20WANG%20Student%20Survey.csv'

df = pd.read_csv(url)
df['1. My primary educational background'].value_counts()
# Out:
# 1. My primary educational background
# STEM (Science, Technology, Engineering, Math)              19
# Social Science (History, Philosophy, Education, etc. )      1
# Criminal Justice with some Software Engineering courses     1
# Name: count, dtype: int64

# %%
# Now, let's make a pie chart!

import plotly.express as px

df_job_dist = df  # One column of data in pandas is called a "series"
df_job_dist = df_job_dist.reset_index()  # Turn into a DataFrame

df_job_dist

#fig = px.bar(df_job_dist, x='1. My primary educational background', y='count')
# Out:
#     index                   Timestamp  \
# 0       0   2024/08/18 8:33:50 PM AST
# 1       1   2024/08/18 8:33:54 PM AST
# 2       2  2024/08/19 10:33:47 AM AST
# 3       3  2024/08/19 12:38:37 PM AST
# 4       4   2024/08/22 3:05:13 AM AST
# 5       5  2024/08/22 10:34:10 AM AST
# 6       6  2024/08/22 10:34:30 AM AST
# 7       7  2024/08/22 10:55:40 PM AST
# 8       8   2024/08/24 2:23:26 PM AST
# 9       9   2024/08/25 1:04:16 PM AST
# 10     10   2024/08/25 7:02:21 PM AST
# 11     11   2024/08/26 3:50:40 PM AST
# 12     12   2024/08/28 4:32:17 PM AST
# 13     13   2024/08/28 5:20:32 PM AST
# 14     14   2024/08/28 5:33:53 PM AST
# 15     15   2024/08/28 6:49:28 PM AST
# 16     16   2024/08/28 6:50:12 PM AST
# 17     17   2024/08/28 6:56:33 PM AST
# 18     18   2024/08/28 6:59:16 PM AST
# 19     19   2024/08/28 7:04:43 PM AST
# 20     20   2024/08/28 7:07:08 PM AST
#
#                  1. My primary educational background  \
# 0       STEM (Science, Technology, Engineering, Math)
# ...

# %%
'''
import pandas as pd
# The below crashes with low memory!  We'll need to break this down.
df = pd.read_csv('https://github.com/wcj365/python-stats-dataviz')
df.sample()
'''
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-9-11ee5a50cff0> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('https://github.com/wcj365/python-stats-dataviz')
#       4 df.sample()
#
# ...

# %%
import csv
import pandas

# Open large .csv file for reading
'''
chunk_count = 100
for chunk in pd.read_csv('https://github.com/wcj365/python-stats-dataviz', low_memory=True, chunksize = chunk_count):
  print(chunk.sample())
'''

with open('https://raw.githubusercontent.com/tsnow2010/DATA601/main/DATA601_Project1/us_released_movies_1972_to_2016.csv','r') as data:
  reader = csv.read(data)
  with open('sample.csv','w') as sample:
    writer = csv.write(sample)
    for i in range(20):
      writer.writerow(reader[i])

df = pd.read_csv('sample.csv')
df.to_string()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-519c4268e28e> in <cell line: 11>()
#       9 '''
#      10
# ---> 11 with open('https://raw.githubusercontent.com/tsnow2010/DATA601/main/DATA601_Project1/us_released_movies_1972_to_2016.csv','r') as data:
#      12   reader = csv.read(data)
#      13   with open('sample.csv','w') as sample:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://raw.githubusercontent.com/tsnow2010/DATA601/main/DATA601_Project1/us_released_movies_1972_to_2016.csv'

# %% [markdown]
# # Homework for Week 3
#
# > Make pie charts for steps 3,4
# >
# > Make bar /pie chart for step 5, but make a distribution of column 12 (the courses everyone is taking)
# >
# > Check session_02.ipynb for reference if needed on dr wangs rep
# >
# > ask copilot for an example for reference!
